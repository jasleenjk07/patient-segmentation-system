# %%
import pandas as pd

# %%
base = pd.read_csv("../data/processed/base_patient_data.csv")

# %%
base.head()
# Out:
#    RIDRETH3  RIAGENDR  RIDAGEYR  DMDEDUC2  DMDMARTL  DMDHHSIZ  INDFMPIR  \
# 0         4         1        69       3.0       4.0         3      0.84
# 1         3         1        54       3.0       1.0         4      1.78
# 2         3         1        72       4.0       1.0         2      4.51
# 3         3         1         9       4.0       1.0         4      2.52
# 4         3         2        73       5.0       1.0         2      5.00
#
#     SEQN  BMXBMI  BPXSY1  BPXDI1  LBDLDL  LBXTC
# 0  73557    26.7   122.0    72.0   103.0  167.0
# 1  73558    28.6   156.0    62.0   103.0  170.0
# 2  73559    28.9   140.0    90.0    56.0  126.0
# 3  73560    17.1   108.0    38.0   103.0  168.0
# 4  73561    19.7   136.0    86.0   101.0  201.0

# %%
base.shape
# Out:
# (9813, 13)

# %%
diet = pd.read_csv("../data/raw/diet.csv")

# %%
diet.head()
# Out:
#     SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0  73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1  73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2  73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3  73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4  73561   59052.357033   39004.892993         1      63.0    2.0     2.0
#
#    DR1DBIH  DR1DAY  DR1LANG  ...  DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0      6.0     2.0      1.0  ...       NaN      NaN       NaN      NaN
# 1      4.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
# 2     18.0     6.0      1.0  ...       NaN      NaN       NaN      NaN
# 3     21.0     3.0      1.0  ...       NaN      NaN       NaN      NaN
# 4     18.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
#
#    DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# 0       NaN      NaN       NaN      NaN       NaN      NaN
# 1       NaN      2.0       NaN      2.0       NaN      2.0
# 2       NaN      NaN       NaN      NaN       NaN      NaN
# 3       NaN      NaN       NaN      NaN       NaN      NaN
# 4       NaN      2.0       NaN      2.0       NaN      2.0
#
# [5 rows x 168 columns]

# %%
diet.shape
# Out:
# (9813, 168)

# %%
diet.columns[:30]
# Out:
# Index(['SEQN', 'WTDRD1', 'WTDR2D', 'DR1DRSTZ', 'DR1EXMER', 'DRABF', 'DRDINT',
#        'DR1DBIH', 'DR1DAY', 'DR1LANG', 'DR1MNRSP', 'DR1HELPD', 'DBQ095Z',
#        'DBD100', 'DRQSPREP', 'DR1STY', 'DR1SKY', 'DRQSDIET', 'DRQSDT1',
#        'DRQSDT2', 'DRQSDT3', 'DRQSDT4', 'DRQSDT5', 'DRQSDT6', 'DRQSDT7',
#        'DRQSDT8', 'DRQSDT9', 'DRQSDT10', 'DRQSDT11', 'DRQSDT12'],
#       dtype='object')

# %%
diet.isnull().sum().sort_values(ascending = False).head(20)
# Out:
# DRQSDT5     9813
# DRQSDT6     9809
# DRQSDT12    9805
# DRD370PQ    9803
# DRD370JQ    9801
# DRD350JQ    9797
# DRQSDT10    9791
# DRD370SQ    9786
# DRQSDT11    9782
# DRQSDT8     9779
# DRD370LQ    9778
# DRQSDT4     9776
# DRD370QQ    9752
# DRQSDT9     9746
# DRQSDT91    9738
# DRD370OQ    9726
# DRD370HQ    9717
# DRD370IQ    9705
# DRD370CQ    9695
# DRQSDT3     9692
# dtype: int64

# %%
[col for col in diet.columns if "DR1T" in col]
# Out:
# ['DR1TNUMF',
#  'DR1TKCAL',
#  'DR1TPROT',
#  'DR1TCARB',
#  'DR1TSUGR',
#  'DR1TFIBE',
#  'DR1TTFAT',
#  'DR1TSFAT',
#  'DR1TMFAT',
#  'DR1TPFAT',
#  'DR1TCHOL',
#  'DR1TATOC',
#  'DR1TATOA',
#  'DR1TRET',
#  'DR1TVARA',
#  'DR1TACAR',
#  'DR1TBCAR',
#  'DR1TCRYP',
#  'DR1TLYCO',
#  'DR1TLZ',
#  'DR1TVB1',
#  'DR1TVB2',
#  'DR1TNIAC',
#  'DR1TVB6',
#  'DR1TFOLA',
#  'DR1TFA',
#  'DR1TFF',
#  'DR1TFDFE',
#  'DR1TCHL',
#  'DR1TVB12',
#  'DR1TB12A',
#  'DR1TVC',
#  'DR1TVD',
#  'DR1TVK',
#  'DR1TCALC',
#  'DR1TPHOS',
#  'DR1TMAGN',
#  'DR1TIRON',
#  'DR1TZINC',
#  'DR1TCOPP',
#  'DR1TSODI',
#  'DR1TPOTA',
#  'DR1TSELE',
#  'DR1TCAFF',
#  'DR1TTHEO',
#  'DR1TALCO',
#  'DR1TMOIS',
#  'DR1TS040',
#  'DR1TS060',
#  'DR1TS080',
#  'DR1TS100',
#  'DR1TS120',
#  'DR1TS140',
#  'DR1TS160',
#  'DR1TS180',
#  'DR1TM161',
#  'DR1TM181',
#  'DR1TM201',
#  'DR1TM221',
#  'DR1TP182',
#  'DR1TP183',
#  'DR1TP184',
#  'DR1TP204',
#  'DR1TP205',
#  'DR1TP225',
#  'DR1TP226',
#  'DR1TWS']

# %%
diet_selected = diet[["SEQN", "DR1TKCAL", "DR1TPROT", "DR1TCARB", "DR1TSUGR", "DR1TTFAT", "DR1TSODI", "DR1TFIBE", "DR1TCHOL", "DR1TALCO"]].copy()

# %%
diet_selected = diet_selected.fillna(diet_selected.median())

# %%
diet_selected.isnull().sum()
# Out:
# SEQN        0
# DR1TKCAL    0
# DR1TPROT    0
# DR1TCARB    0
# DR1TSUGR    0
# DR1TTFAT    0
# DR1TSODI    0
# DR1TFIBE    0
# DR1TCHOL    0
# DR1TALCO    0
# dtype: int64

# %%
merge_diet = base.merge(diet_selected, on = "SEQN", how = "inner")

# %%
merge_diet.shape
# Out:
# (9813, 22)

# %%
merge_diet.head()
# Out:
#    RIDRETH3  RIAGENDR  RIDAGEYR  DMDEDUC2  DMDMARTL  DMDHHSIZ  INDFMPIR  \
# 0         4         1        69       3.0       4.0         3      0.84
# 1         3         1        54       3.0       1.0         4      1.78
# 2         3         1        72       4.0       1.0         2      4.51
# 3         3         1         9       4.0       1.0         4      2.52
# 4         3         2        73       5.0       1.0         2      5.00
#
#     SEQN  BMXBMI  BPXSY1  ...  LBXTC  DR1TKCAL  DR1TPROT  DR1TCARB  DR1TSUGR  \
# 0  73557    26.7   122.0  ...  167.0    1574.0     43.63    239.59    176.47
# 1  73558    28.6   156.0  ...  170.0    5062.0    338.13    423.78     44.99
# 2  73559    28.9   140.0  ...  126.0    1743.0     64.61    224.39    102.90
# 3  73560    17.1   108.0  ...  168.0    1490.0     77.75    162.92     80.58
# 4  73561    19.7   136.0  ...  201.0    1421.0     55.24    178.20     87.78
#
#    DR1TTFAT  DR1TSODI  DR1TFIBE  DR1TCHOL  DR1TALCO
# 0     52.81    1323.0      10.8     209.0       0.0
# 1    124.29    9726.0      16.7    2584.0     119.0
# 2     65.97    2943.0       9.9      88.0       0.0
# 3     58.27    2745.0      10.6     187.0       0.0
# 4     55.36     797.0      12.3      41.0       0.0
#
# [5 rows x 22 columns]

# %%
merge_diet.to_csv("../data/processed/base_plus_diet.csv", index = False)

# %%
features_diet = merge_diet.drop(columns = ["SEQN"]).copy()

# %%
features_diet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9813 entries, 0 to 9812
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   RIDRETH3  9813 non-null   int64
#  1   RIAGENDR  9813 non-null   int64
#  2   RIDAGEYR  9813 non-null   int64
#  3   DMDEDUC2  9813 non-null   float64
#  4   DMDMARTL  9813 non-null   float64
#  5   DMDHHSIZ  9813 non-null   int64
#  6   INDFMPIR  9813 non-null   float64
#  7   BMXBMI    9813 non-null   float64
#  8   BPXSY1    9813 non-null   float64
#  9   BPXDI1    9813 non-null   float64
#  10  LBDLDL    9813 non-null   float64
#  11  LBXTC     9813 non-null   float64
#  12  DR1TKCAL  9813 non-null   float64
#  13  DR1TPROT  9813 non-null   float64
#  14  DR1TCARB  9813 non-null   float64
#  15  DR1TSUGR  9813 non-null   float64
#  16  DR1TTFAT  9813 non-null   float64
#  17  DR1TSODI  9813 non-null   float64
#  18  DR1TFIBE  9813 non-null   float64
#  19  DR1TCHOL  9813 non-null   float64
#  20  DR1TALCO  9813 non-null   float64
# dtypes: float64(17), int64(4)
# memory usage: 1.6 MB

# %%
features_diet.select_dtypes(include=["int64", "float64"]).columns
# Out:
# Index(['RIDRETH3', 'RIAGENDR', 'RIDAGEYR', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ',
#        'INDFMPIR', 'BMXBMI', 'BPXSY1', 'BPXDI1', 'LBDLDL', 'LBXTC', 'DR1TKCAL',
#        'DR1TPROT', 'DR1TCARB', 'DR1TSUGR', 'DR1TTFAT', 'DR1TSODI', 'DR1TFIBE',
#        'DR1TCHOL', 'DR1TALCO'],
#       dtype='object')

# %%
features_diet.select_dtypes(include=["object", "category"]).columns
# Out:
# Index([], dtype='object')

# %%
features_diet.nunique().sort_values()
# Out:
# RIAGENDR       2
# RIDRETH3       6
# DMDEDUC2       7
# DMDHHSIZ       7
# DMDMARTL       8
# BPXDI1        59
# BPXSY1        71
# RIDAGEYR      81
# LBDLDL       195
# LBXTC        253
# DR1TALCO     408
# INDFMPIR     440
# BMXBMI       440
# DR1TFIBE     539
# DR1TCHOL     982
# DR1TKCAL    3132
# DR1TSODI    4487
# DR1TPROT    6206
# DR1TTFAT    6292
# DR1TSUGR    6919
# DR1TCARB    7647
# dtype: int64

# %%
features_diet["RIAGENDR"] = features_diet["RIAGENDR"].map({1:0, 2:1})

# %%
feature_diet = pd.get_dummies(
    features_diet,
    columns = ["RIDRETH3", "DMDMARTL"],
    drop_first = True
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features_diet = scaler.fit_transform(features_diet)

scaled_df4 = pd.DataFrame(scaled_features_diet, columns = features_diet.columns)
scaled_df4.head()
# Out:
#    RIDRETH3  RIAGENDR  RIDAGEYR  DMDEDUC2  DMDMARTL  DMDHHSIZ  INDFMPIR  \
# 0  0.449104 -1.015508  1.531807 -0.757038  0.984480 -0.510511 -0.869447
# 1 -0.172835 -1.015508  0.916959 -0.757038 -0.415825  0.069309 -0.272224
# 2 -0.172835 -1.015508  1.654776  0.284579 -0.415825 -1.090330  1.462267
# 3 -0.172835 -1.015508 -0.927582  0.284579 -0.415825  0.069309  0.197931
# 4 -0.172835  0.984729  1.695766  1.326196 -0.415825 -1.090330  1.773585
#
#      BMXBMI    BPXSY1    BPXDI1  ...     LBXTC  DR1TKCAL  DR1TPROT  DR1TCARB  \
# 0  0.143520  0.287286  0.482300  ... -0.318788 -0.400421 -0.712954 -0.005251
# 1  0.392024  2.483279 -0.299621  ... -0.235790  3.392209  6.333324  1.585952
# 2  0.431261  1.449871  1.889756  ... -1.453100 -0.216662 -0.210981 -0.136562
# 3 -1.112078 -0.616946 -2.176229  ... -0.291122 -0.491758  0.103410 -0.667597
# 4 -0.772020  1.191519  1.576988  ...  0.621861 -0.566784 -0.435170 -0.535594
#
#    DR1TSUGR  DR1TTFAT  DR1TSODI  DR1TFIBE   DR1TCHOL  DR1TALCO
# 0  1.008695 -0.496824 -1.067015 -0.442560  -0.202287 -0.250901
# 1 -0.908680  1.183853  3.879750  0.180095  10.641174  5.385905
# 2 -0.064178 -0.187399 -0.113337 -0.537542  -0.754733 -0.250901
# 3 -0.389671 -0.368445 -0.229898 -0.463667  -0.302732 -0.250901
# 4 -0.284673 -0.436867 -1.376667 -0.284258  -0.969319 -0.250901
#
# [5 rows x 21 columns]

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia4 = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, random_state = 42)
    kmeans.fit(scaled_df4)
    inertia4.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(range(1,11), inertia4, marker = 'o')
plt.title("Elbow Method - Full Patient Dataset (Demographic + Examination + Labs + Diet)")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia / WCSS")
plt.show()

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

for k in range(2,7):
    kmeans = KMeans(n_clusters = k, random_state = 42)
    labels = kmeans.fit_predict(scaled_df4)
    score = silhouette_score(scaled_df4, labels)
    print(f"k={k}, silhouette score={score}")
# Out:
# k=2, silhouette score=0.22543460559934528
# k=3, silhouette score=0.13792421973000443
# k=4, silhouette score=0.12994359300199113
# k=5, silhouette score=0.12294220333143642
# k=6, silhouette score=0.06464673427004672

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.mixture import GaussianMixture
